# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('combined.csv')
df
# Out:
#         latitude   longitude blk_no            road_name  postal_code  \
# 0       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# 1       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# 2       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# 3       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# 4       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# ...          ...         ...    ...                  ...          ...
# 203824  1.421073  103.843117   674B      YISHUN AVENUE 4       762674
# 203825  1.421073  103.843117   674B      YISHUN AVENUE 4       762674
# 203826  1.421073  103.843117   674B      YISHUN AVENUE 4       762674
# 203827  1.421073  103.843117   674B      YISHUN AVENUE 4       762674
# 203828  1.421073  103.843117   674B      YISHUN AVENUE 4       762674
#
#                      address      cbd_dist  min_dist_mrt    month        town  \
# 0       174 ANG MO KIO AVE 4  10296.855747   1096.947897  2015-01  ANG MO KIO
# 1       174 ANG MO KIO AVE 4  10296.855747   1096.947897  2015-12  ANG MO KIO
# 2       174 ANG MO KIO AVE 4  10296.855747   1096.947897  2016-05  ANG MO KIO
# 3       174 ANG MO KIO AVE 4  10296.855747   1096.947897  2016-06  ANG MO KIO
# 4       174 ANG MO KIO AVE 4  10296.855747   1096.947897  2016-11  ANG MO KIO
# ...                      ...           ...           ...      ...         ...
# 203824     674B YISHUN AVE 4  15294.493180   1199.607851  2023-04      YISHUN
# 203825     674B YISHUN AVE 4  15294.493180   1199.607851  2023-05      YISHUN
# 203826     674B YISHUN AVE 4  15294.493180   1199.607851  2023-07      YISHUN
# 203827     674B YISHUN AVE 4  15294.493180   1199.607851  2023-07      YISHUN
# 203828     674B YISHUN AVE 4  15294.493180   1199.607851  2023-08      YISHUN
#
#        flat_type block       street_name storey_range  floor_area_sqm  \
# 0         3 ROOM   174  ANG MO KIO AVE 4     07 TO 09            60.0
# 1         3 ROOM   174  ANG MO KIO AVE 4     10 TO 12            60.0
# 2         3 ROOM   174  ANG MO KIO AVE 4     04 TO 06            69.0
# 3         2 ROOM   174  ANG MO KIO AVE 4     07 TO 09            45.0
# 4         3 ROOM   174  ANG MO KIO AVE 4     04 TO 06            61.0
# ...          ...   ...               ...          ...             ...
# 203824    5 ROOM  674B      YISHUN AVE 4     10 TO 12           112.0
# 203825    5 ROOM  674B      YISHUN AVE 4     04 TO 06           112.0
# 203826    5 ROOM  674B      YISHUN AVE 4     10 TO 12           112.0
# 203827    5 ROOM  674B      YISHUN AVE 4     07 TO 09           112.0
# 203828    5 ROOM  674B      YISHUN AVE 4     07 TO 09           112.0
#
#        flat_model  lease_commence_date  resale_price     remaining_lease  \
# 0        Improved                 1986      255000.0                  70
# 1        Improved                 1986      275000.0                  69
# 2        Improved                 1986      310000.0                  68
# 3        Improved                 1986      253000.0                  68
# 4        Improved                 1986      290000.0                  68
# ...           ...                  ...           ...                 ...
# 203824   Improved                 2018      715000.0  94 years 07 months
# 203825   Improved                 2018      665000.0  94 years 07 months
# 203826   Improved                 2018      715000.0  94 years 05 months
# 203827   Improved                 2018      720000.0  94 years 05 months
# 203828   Improved                 2018      728000.0  94 years 03 months
#
#         lease_remain_years
# 0                       62
# 1                       62
# 2                       62
# 3                       62
# 4                       62
# ...                    ...
# 203824                  94
# 203825                  94
# 203826                  94
# 203827                  94
# 203828                  94
#
# [203829 rows x 20 columns]

# %%
df.dtypes
# Out:
# latitude               float64
# longitude              float64
# blk_no                  object
# road_name               object
# postal_code              int64
# address                 object
# cbd_dist               float64
# min_dist_mrt           float64
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# resale_price           float64
# remaining_lease         object
# lease_remain_years       int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# latitude               0
# longitude              0
# blk_no                 0
# road_name              0
# postal_code            0
# address                0
# cbd_dist               0
# min_dist_mrt           0
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# resale_price           0
# remaining_lease        0
# lease_remain_years     0
# dtype: int64

# %% [markdown]
# # Minor Data Preprocessing for Combined Data

# %%
import statistics

def get_median(x):
    split_list = x.split(' TO ')
    float_list = [float(i) for i in split_list]
    median = statistics.median(float_list)
    return median

df['storey_median'] = df['storey_range'].apply(lambda x: get_median(x))
df
# Out:
#         latitude   longitude blk_no            road_name  postal_code  \
# 0       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# 1       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# 2       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# 3       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# 4       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# ...          ...         ...    ...                  ...          ...
# 203824  1.421073  103.843117   674B      YISHUN AVENUE 4       762674
# 203825  1.421073  103.843117   674B      YISHUN AVENUE 4       762674
# 203826  1.421073  103.843117   674B      YISHUN AVENUE 4       762674
# 203827  1.421073  103.843117   674B      YISHUN AVENUE 4       762674
# 203828  1.421073  103.843117   674B      YISHUN AVENUE 4       762674
#
#                      address      cbd_dist  min_dist_mrt    month        town  \
# 0       174 ANG MO KIO AVE 4  10296.855747   1096.947897  2015-01  ANG MO KIO
# 1       174 ANG MO KIO AVE 4  10296.855747   1096.947897  2015-12  ANG MO KIO
# 2       174 ANG MO KIO AVE 4  10296.855747   1096.947897  2016-05  ANG MO KIO
# 3       174 ANG MO KIO AVE 4  10296.855747   1096.947897  2016-06  ANG MO KIO
# 4       174 ANG MO KIO AVE 4  10296.855747   1096.947897  2016-11  ANG MO KIO
# ...                      ...           ...           ...      ...         ...
# 203824     674B YISHUN AVE 4  15294.493180   1199.607851  2023-04      YISHUN
# 203825     674B YISHUN AVE 4  15294.493180   1199.607851  2023-05      YISHUN
# 203826     674B YISHUN AVE 4  15294.493180   1199.607851  2023-07      YISHUN
# 203827     674B YISHUN AVE 4  15294.493180   1199.607851  2023-07      YISHUN
# 203828     674B YISHUN AVE 4  15294.493180   1199.607851  2023-08      YISHUN
#
#         ... block       street_name storey_range floor_area_sqm  flat_model  \
# 0       ...   174  ANG MO KIO AVE 4     07 TO 09           60.0    Improved
# 1       ...   174  ANG MO KIO AVE 4     10 TO 12           60.0    Improved
# 2       ...   174  ANG MO KIO AVE 4     04 TO 06           69.0    Improved
# 3       ...   174  ANG MO KIO AVE 4     07 TO 09           45.0    Improved
# 4       ...   174  ANG MO KIO AVE 4     04 TO 06           61.0    Improved
# ...     ...   ...               ...          ...            ...         ...
# 203824  ...  674B      YISHUN AVE 4     10 TO 12          112.0    Improved
# 203825  ...  674B      YISHUN AVE 4     04 TO 06          112.0    Improved
# 203826  ...  674B      YISHUN AVE 4     10 TO 12          112.0    Improved
# 203827  ...  674B      YISHUN AVE 4     07 TO 09          112.0    Improved
# 203828  ...  674B      YISHUN AVE 4     07 TO 09          112.0    Improved
#
#        lease_commence_date  resale_price     remaining_lease  \
# 0                     1986      255000.0                  70
# 1                     1986      275000.0                  69
# 2                     1986      310000.0                  68
# 3                     1986      253000.0                  68
# 4                     1986      290000.0                  68
# ...                    ...           ...                 ...
# 203824                2018      715000.0  94 years 07 months
# 203825                2018      665000.0  94 years 07 months
# 203826                2018      715000.0  94 years 05 months
# 203827                2018      720000.0  94 years 05 months
# 203828                2018      728000.0  94 years 03 months
#
#        lease_remain_years  storey_median
# 0                      62            8.0
# 1                      62           11.0
# 2                      62            5.0
# 3                      62            8.0
# 4                      62            5.0
# ...                   ...            ...
# 203824                 94           11.0
# 203825                 94            5.0
# 203826                 94           11.0
# 203827                 94            8.0
# 203828                 94            8.0
#
# [203829 rows x 21 columns]

# %%
scope_df = df[['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median','resale_price']]
scope_df
# Out:
#             cbd_dist  min_dist_mrt  floor_area_sqm  lease_remain_years  \
# 0       10296.855747   1096.947897            60.0                  62
# 1       10296.855747   1096.947897            60.0                  62
# 2       10296.855747   1096.947897            69.0                  62
# 3       10296.855747   1096.947897            45.0                  62
# 4       10296.855747   1096.947897            61.0                  62
# ...              ...           ...             ...                 ...
# 203824  15294.493180   1199.607851           112.0                  94
# 203825  15294.493180   1199.607851           112.0                  94
# 203826  15294.493180   1199.607851           112.0                  94
# 203827  15294.493180   1199.607851           112.0                  94
# 203828  15294.493180   1199.607851           112.0                  94
#
#         storey_median  resale_price
# 0                 8.0      255000.0
# 1                11.0      275000.0
# 2                 5.0      310000.0
# 3                 8.0      253000.0
# 4                 5.0      290000.0
# ...               ...           ...
# 203824           11.0      715000.0
# 203825            5.0      665000.0
# 203826           11.0      715000.0
# 203827            8.0      720000.0
# 203828            8.0      728000.0
#
# [203829 rows x 6 columns]

# %%
scope_df = scope_df.drop_duplicates()
scope_df
# Out:
#             cbd_dist  min_dist_mrt  floor_area_sqm  lease_remain_years  \
# 0       10296.855747   1096.947897            60.0                  62
# 1       10296.855747   1096.947897            60.0                  62
# 2       10296.855747   1096.947897            69.0                  62
# 3       10296.855747   1096.947897            45.0                  62
# 4       10296.855747   1096.947897            61.0                  62
# ...              ...           ...             ...                 ...
# 203823  15294.493180   1199.607851           112.0                  94
# 203824  15294.493180   1199.607851           112.0                  94
# 203825  15294.493180   1199.607851           112.0                  94
# 203827  15294.493180   1199.607851           112.0                  94
# 203828  15294.493180   1199.607851           112.0                  94
#
#         storey_median  resale_price
# 0                 8.0      255000.0
# 1                11.0      275000.0
# 2                 5.0      310000.0
# 3                 8.0      253000.0
# 4                 5.0      290000.0
# ...               ...           ...
# 203823           11.0      708000.0
# 203824           11.0      715000.0
# 203825            5.0      665000.0
# 203827            8.0      720000.0
# 203828            8.0      728000.0
#
# [197521 rows x 6 columns]

# %% [markdown]
# # Checking and Handling for Skewness in the Data

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# List of columns(continuous variables) for finding skewness
col = ['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median','resale_price']

for i in col:
    plt.figure(figsize=(8, 6))  
    sns.boxplot(data=df, x=i)
    plt.title(f'Boxplot of {i}')
    plt.xlabel(i)
    plt.show()

# %%
df1 = scope_df

# %%
# Apply a logarithmic transformation to the required columns only.
# One need to apply it and check, in some cases it will handle the skewness, and in other cases it might not have a great 
                                                                # effect on the data, so no need to apply for that columns
    
df1['floor_area_sqm'] = np.log(df1['floor_area_sqm'])
sns.boxplot(x='floor_area_sqm', data=df1)
plt.show()

df1['storey_median'] = np.log(df1['storey_median'])
sns.boxplot(x='storey_median', data=df1)
plt.show()

df1['resale_price'] = np.log(df1['resale_price'])
sns.boxplot(x='resale_price', data=df1)
plt.show()

# %%
df1.dtypes
# Out:
# cbd_dist              float64
# min_dist_mrt          float64
# floor_area_sqm        float64
# lease_remain_years      int64
# storey_median         float64
# resale_price          float64
# dtype: object

# %%
import seaborn as sns

corrMatrix = df1.corr()
plt.figure(figsize=(15, 10))
plt.title("Correlation Heatmap")
sns.heatmap(
    corrMatrix, 
    xticklabels=corrMatrix.columns,
    yticklabels=corrMatrix.columns,
    cmap='RdBu', 
    annot=True
)
# Out:
# <Axes: title={'center': 'Correlation Heatmap'}>

# %% [markdown]
# # Encoding Data

# %%
from sklearn.preprocessing import StandardScaler

X=df1[['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median']]
y=df1['resale_price']

# Normalizing the encoded data
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
test_dataframe = pd.DataFrame(X)
test_dataframe
# Out:
#                0         1         2         3         4
# 0      -0.485422  0.585945 -1.776252 -0.665658  0.212504
# 1      -0.485422  0.585945 -1.776252 -0.665658  0.655724
# 2      -0.485422  0.585945 -1.230246 -0.665658 -0.441641
# 3      -0.485422  0.585945 -2.900133 -0.665658  0.212504
# 4      -0.485422  0.585945 -1.711677 -0.665658 -0.441641
# ...          ...       ...       ...       ...       ...
# 197516  0.649489  0.808623  0.662119  1.708006  0.655724
# 197517  0.649489  0.808623  0.662119  1.708006  0.655724
# 197518  0.649489  0.808623  0.662119  1.708006 -0.441641
# 197519  0.649489  0.808623  0.662119  1.708006  0.212504
# 197520  0.649489  0.808623  0.662119  1.708006  0.212504
#
# [197521 rows x 5 columns]

# %% [markdown]
# # Splitting the Data for Training and Testing Purposes

# %%
from sklearn.model_selection import train_test_split

# test and train split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# # Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import GridSearchCV

# Decision Tree Regressor
dtr = DecisionTreeRegressor()

# hyperparameters
param_grid = {
    'max_depth': [2, 5, 10, 15, 20, 22],
    'min_samples_split': [2, 3, 4, 5],
    'min_samples_leaf': [2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20],
    'max_features': ['auto', 'sqrt', 'log2']
}

# gridsearchcv
grid_search = GridSearchCV(estimator=dtr, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)
print("Best hyperparameters:", grid_search.best_params_)
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# evalution metrics
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
print(" ")
print('Mean squared error:', mse)
print('Mean Absolute Error', mae)
print('Root Mean squared error:', rmse)
print(" ")
print('R-squared:', r2)
# Out:
# Best hyperparameters: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 9, 'min_samples_split': 2}
#
# Mean squared error: 0.015043350476564599
# Mean Absolute Error 0.09691612256161734
# Root Mean squared error: 0.12265133703537275
#
# R-squared: 0.8614444428695984

# %% [markdown]
# # Testing Our Trained Model (Decision Tree Regressor)

# %%
new_sample = np.array([[8740, 999, np.log(44), 55, np.log(11)]])
new_sample = scaler.transform(new_sample[:, :5])
new_pred = best_model.predict(new_sample)[0]
np.exp(new_pred)
# Out:
# 240572.4456343715

# %%
# Saving the model
import pickle
with open('modelsml.pkl', 'wb') as file:
    pickle.dump(best_model, file)
with open('scalersml.pkl', 'wb') as f:
    pickle.dump(scaler, f)
